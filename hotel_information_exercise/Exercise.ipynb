# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_excel('hotel.xlsx', index_col=0)

# %%
df.head()
# Out:
#            ADR_USD  city_id  hotel_id  star_rating accommadation_type_name  \
# #
# 113.0   354.780000   5085.0   85582.0          4.0                   Hotel
# 119.0   135.700000   5085.0   85582.0          4.0                   Hotel
# 213.0   140.946667   5085.0   85582.0          4.0                   Hotel
# 635.0   176.020000   5085.0   85582.0          4.0                   Hotel
# 1006.0  237.626667   5085.0   85582.0          4.0                   Hotel
#
#        chain_hotel booking_date checkin_date checkout_date  \
# #
# 113.0    non-chain   2016-08-23   2016-10-12    2016-10-13
# 119.0    non-chain   2016-08-24   2016-10-23    2016-10-25
# 213.0    non-chain   2016-08-30   2016-10-23    2016-10-26
# 635.0    non-chain   2016-09-16   2016-10-26    2016-10-27
# 1006.0   non-chain   2016-09-24   2016-10-23    2016-10-26
#
#         Total Booked Duration (Nights)  ...  Check in month  Hotel Label  \
# #                                       ...
# 113.0                              1.0  ...            10.0            C
# 119.0                              2.0  ...            10.0            C
# 213.0                              3.0  ...            10.0            C
# 635.0                              1.0  ...            10.0            C
# 1006.0                             3.0  ...            10.0            C
#
#         Major holiday Duration from previous booking  Total Booking Points  \
# #
# 113.0             0.0                            NaN                     1
# 119.0             0.0                            1.0                     2
# 213.0             0.0                            6.0                     5
# 635.0             0.0                           17.0                     1
# 1006.0            0.0                            8.0                     8
#
#         Period Popularity  \
# #
# 113.0            1.000000
# 119.0            1.000000
# 213.0            1.666667
# 635.0            1.000000
# 1006.0           2.666667
#
#         Normalized hotel rate (Price / Average of hotel rates)  \
# #
# 113.0                                            1.538372
# 119.0                                            0.588413
# 213.0                                            0.611163
# 635.0                                            0.763246
# 1006.0                                           1.030380
#
#         Normalized Booking Rate (NBR)  Period Popularity.1 Pre-Booked Duration
# #
# 113.0                            High                Ahead               Early
# 119.0                             Low                Ahead               Early
# 213.0                             Low              Average               Early
# 635.0                             Low                Ahead               Early
# 1006.0                           High              Average               Early
#
# [5 rows x 22 columns]
